# %%
import pandas as pd

# %% [markdown]
# # 数据类型

# %% [markdown]
# Pandas 的数据类型主要有以下几种，它们分别是：Series（一维数组），DataFrame（二维数组），Panel（三维数组），Panel4D（四维数组），PanelND（更多维数组）。其中 Series 和 DataFrame 应用的最为广泛，几乎占据了使用频率 90% 以上。

# %% [markdown]
# ## Series

# %%
# 基于字典创建
s = pd.Series({'a': 10, 'b': 20, 'c': 30})
s
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
import numpy as np

# 基于Numpy创建
s = pd.Series(np.random.randn(5))
s
# Out:
# 0   -0.240677
# 1   -1.279610
# 2    0.389179
# 3    0.249023
# 4   -0.692666
# dtype: float64

# %% [markdown]
# ## DataFrame

# %%
df = pd.DataFrame({'one': pd.Series([1, 2, 3]),
                   'two': pd.Series([4, 5, 6])})
df
# Out:
#    one  two
# 0    1    4
# 1    2    5
# 2    3    6

# %%
df = pd.DataFrame({'one': [1, 2, 3],
                   'two': [4, 5, 6]})
df
# Out:
#    one  two
# 0    1    4
# 1    2    5
# 2    3    6

# %%
df = pd.DataFrame([{'one': 1, 'two': 4},
                   {'one': 2, 'two': 5},
                   {'one': 3, 'two': 6}])
df
# Out:
#    one  two
# 0    1    4
# 1    2    5
# 2    3    6

# %%
pd.DataFrame(np.random.randint(5, size=(2, 4)))
# Out:
#    0  1  2  3
# 0  0  3  0  2
# 1  2  2  0  1

# %%
# Series没有列索引
pd.Series(np.random.randint(5, size=(5,)))
# Out:
# 0    3
# 1    1
# 2    2
# 3    3
# 4    2
# dtype: int32

# %%
pd.DataFrame(np.random.randint(5, size=(5,)))
# Out:
#    0
# 0  1
# 1  1
# 2  3
# 3  3
# 4  1

# %% [markdown]
# # 数据读取

# %%
df = pd.read_csv("https://labfile.oss.aliyuncs.com/courses/906/los_census.csv")
df
# Out:
#      Zip Code  Total Population  Median Age  Total Males  Total Females  \
# 0       91371                 1        73.5            0              1
# 1       90001             57110        26.6        28468          28642
# 2       90002             51223        25.5        24876          26347
# 3       90003             66266        26.3        32631          33635
# 4       90004             62180        34.8        31302          30878
# ..        ...               ...         ...          ...            ...
# 314     93552             38158        28.4        18711          19447
# 315     93553              2138        43.3         1121           1017
# 316     93560             18910        32.4         9491           9419
# 317     93563               388        44.5          263            125
# 318     93591              7285        30.9         3653           3632
#
#      Total Households  Average Household Size
# 0                   1                    1.00
# 1               12971                    4.40
# 2               11731                    4.36
# 3               15642                    4.22
# 4               22547                    2.73
# ..                ...                     ...
# 314              9690                    3.93
# 315               816                    2.62
# 316              6469                    2.92
# 317               103                    2.53
# 318              1982                    3.67
#
# [319 rows x 7 columns]

# %%
# 默认显示前 5 条
df.head()
# Out:
#    Zip Code  Total Population  Median Age  Total Males  Total Females  \
# 0     91371                 1        73.5            0              1
# 1     90001             57110        26.6        28468          28642
# 2     90002             51223        25.5        24876          26347
# 3     90003             66266        26.3        32631          33635
# 4     90004             62180        34.8        31302          30878
#
#    Total Households  Average Household Size
# 0                 1                    1.00
# 1             12971                    4.40
# 2             11731                    4.36
# 3             15642                    4.22
# 4             22547                    2.73

# %%
# 指定显示后 7 条
df.tail(7)
# Out:
#      Zip Code  Total Population  Median Age  Total Males  Total Females  \
# 312     93550             74929        27.5        36414          38515
# 313     93551             50798        37.0        25056          25742
# 314     93552             38158        28.4        18711          19447
# 315     93553              2138        43.3         1121           1017
# 316     93560             18910        32.4         9491           9419
# 317     93563               388        44.5          263            125
# 318     93591              7285        30.9         3653           3632
#
#      Total Households  Average Household Size
# 312             20864                    3.58
# 313             15963                    3.18
# 314              9690                    3.93
# 315               816                    2.62
# 316              6469                    2.92
# 317               103                    2.53
# 318              1982                    3.67

# %%
# 默认对每一列操作
df.describe()
# Out:
#            Zip Code  Total Population  Median Age   Total Males  \
# count    319.000000        319.000000  319.000000    319.000000
# mean   91000.673981      33241.341693   36.527586  16391.564263
# std      908.360203      21644.417455    8.692999  10747.495566
# min    90001.000000          0.000000    0.000000      0.000000
# 25%    90243.500000      19318.500000   32.400000   9763.500000
# 50%    90807.000000      31481.000000   37.100000  15283.000000
# 75%    91417.000000      44978.000000   41.000000  22219.500000
# max    93591.000000     105549.000000   74.000000  52794.000000
#
#        Total Females  Total Households  Average Household Size
# count     319.000000        319.000000              319.000000
# mean    16849.777429      10964.570533                2.828119
# std     10934.986468       6270.646400                0.835658
# min         0.000000          0.000000                0.000000
# 25%      9633.500000       6765.500000                2.435000
# 50%     16202.000000      10968.000000                2.830000
# 75%     22690.500000      14889.500000                3.320000
# max     53185.000000      31087.000000                4.670000

# %%
# DF 转化为 NP数组
df.values
# Out:
# array([[9.1371e+04, 1.0000e+00, 7.3500e+01, ..., 1.0000e+00, 1.0000e+00,
#         1.0000e+00],
#        [9.0001e+04, 5.7110e+04, 2.6600e+01, ..., 2.8642e+04, 1.2971e+04,
#         4.4000e+00],
#        [9.0002e+04, 5.1223e+04, 2.5500e+01, ..., 2.6347e+04, 1.1731e+04,
#         4.3600e+00],
#        ...,
#        [9.3560e+04, 1.8910e+04, 3.2400e+01, ..., 9.4190e+03, 6.4690e+03,
#         2.9200e+00],
#        [9.3563e+04, 3.8800e+02, 4.4500e+01, ..., 1.2500e+02, 1.0300e+02,
#         2.5300e+00],
#        [9.3591e+04, 7.2850e+03, 3.0900e+01, ..., 3.6320e+03, 1.9820e+03,
#         3.6700e+00]])

# %%
# 查看索引
df.index
# Out:
# RangeIndex(start=0, stop=319, step=1)

# %%
# 查看列名
df.columns
# Out:
# Index(['Zip Code', 'Total Population', 'Median Age', 'Total Males',
#        'Total Females', 'Total Households', 'Average Household Size'],
#       dtype='object')

# %%
# 查看形状
df.shape
# Out:
# (319, 7)

# %% [markdown]
# # 数据选择

# %% [markdown]
# ## 基于索引数字选择

# %%
df.iloc[:3]
# Out:
#    Zip Code  Total Population  Median Age  Total Males  Total Females  \
# 0     91371                 1        73.5            0              1
# 1     90001             57110        26.6        28468          28642
# 2     90002             51223        25.5        24876          26347
#
#    Total Households  Average Household Size
# 0                 1                    1.00
# 1             12971                    4.40
# 2             11731                    4.36

# %%
df.iloc[5]
# Out:
# Zip Code                  90005.0
# Total Population          37681.0
# Median Age                   33.9
# Total Males               19299.0
# Total Females             18382.0
# Total Households          15044.0
# Average Household Size        2.5
# Name: 5, dtype: float64

# %%
df.iloc[[1, 3, 5]]
# Out:
#    Zip Code  Total Population  Median Age  Total Males  Total Females  \
# 1     90001             57110        26.6        28468          28642
# 3     90003             66266        26.3        32631          33635
# 5     90005             37681        33.9        19299          18382
#
#    Total Households  Average Household Size
# 1             12971                    4.40
# 3             15642                    4.22
# 5             15044                    2.50

# %%
# 选择列
df.iloc[:, 1:4]
# Out:
#      Total Population  Median Age  Total Males
# 0                   1        73.5            0
# 1               57110        26.6        28468
# 2               51223        25.5        24876
# 3               66266        26.3        32631
# 4               62180        34.8        31302
# ..                ...         ...          ...
# 314             38158        28.4        18711
# 315              2138        43.3         1121
# 316             18910        32.4         9491
# 317               388        44.5          263
# 318              7285        30.9         3653
#
# [319 rows x 3 columns]

# %% [markdown]
# ## 基于标签名称选择

# %%
df.loc[0:2]
# Out:
#    Zip Code  Total Population  Median Age  Total Males  Total Females  \
# 0     91371                 1        73.5            0              1
# 1     90001             57110        26.6        28468          28642
# 2     90002             51223        25.5        24876          26347
#
#    Total Households  Average Household Size
# 0                 1                    1.00
# 1             12971                    4.40
# 2             11731                    4.36

# %%
df.loc[[0, 2, 4]]
# Out:
#    Zip Code  Total Population  Median Age  Total Males  Total Females  \
# 0     91371                 1        73.5            0              1
# 2     90002             51223        25.5        24876          26347
# 4     90004             62180        34.8        31302          30878
#
#    Total Households  Average Household Size
# 0                 1                    1.00
# 2             11731                    4.36
# 4             22547                    2.73

# %%
df.loc[:, 'Total Population':'Total Males']
# Out:
#      Total Population  Median Age  Total Males
# 0                   1        73.5            0
# 1               57110        26.6        28468
# 2               51223        25.5        24876
# 3               66266        26.3        32631
# 4               62180        34.8        31302
# ..                ...         ...          ...
# 314             38158        28.4        18711
# 315              2138        43.3         1121
# 316             18910        32.4         9491
# 317               388        44.5          263
# 318              7285        30.9         3653
#
# [319 rows x 3 columns]

# %%
df.loc[[0,2], 'Median Age':]
# Out:
#    Median Age  Total Males  Total Females  Total Households  \
# 0        73.5            0              1                 1
# 2        25.5        24876          26347             11731
#
#    Average Household Size
# 0                    1.00
# 2                    4.36

# %% [markdown]
# # 数据删减

# %%
df.drop(labels=['Median Age', 'Total Males'], axis=1)
# Out:
#      Zip Code  Total Population  Total Females  Total Households  \
# 0       91371                 1              1                 1
# 1       90001             57110          28642             12971
# 2       90002             51223          26347             11731
# 3       90003             66266          33635             15642
# 4       90004             62180          30878             22547
# ..        ...               ...            ...               ...
# 314     93552             38158          19447              9690
# 315     93553              2138           1017               816
# 316     93560             18910           9419              6469
# 317     93563               388            125               103
# 318     93591              7285           3632              1982
#
#      Average Household Size
# 0                      1.00
# 1                      4.40
# 2                      4.36
# 3                      4.22
# 4                      2.73
# ..                      ...
# 314                    3.93
# 315                    2.62
# 316                    2.92
# 317                    2.53
# 318                    3.67
#
# [319 rows x 5 columns]

# %%
df.drop_duplicates()
# Out:
#      Zip Code  Total Population  Median Age  Total Males  Total Females  \
# 0       91371                 1        73.5            0              1
# 1       90001             57110        26.6        28468          28642
# 2       90002             51223        25.5        24876          26347
# 3       90003             66266        26.3        32631          33635
# 4       90004             62180        34.8        31302          30878
# ..        ...               ...         ...          ...            ...
# 314     93552             38158        28.4        18711          19447
# 315     93553              2138        43.3         1121           1017
# 316     93560             18910        32.4         9491           9419
# 317     93563               388        44.5          263            125
# 318     93591              7285        30.9         3653           3632
#
#      Total Households  Average Household Size
# 0                   1                    1.00
# 1               12971                    4.40
# 2               11731                    4.36
# 3               15642                    4.22
# 4               22547                    2.73
# ..                ...                     ...
# 314              9690                    3.93
# 315               816                    2.62
# 316              6469                    2.92
# 317               103                    2.53
# 318              1982                    3.67
#
# [319 rows x 7 columns]

# %%
df.dropna()
# Out:
#      Zip Code  Total Population  Median Age  Total Males  Total Females  \
# 0       91371                 1        73.5            0              1
# 1       90001             57110        26.6        28468          28642
# 2       90002             51223        25.5        24876          26347
# 3       90003             66266        26.3        32631          33635
# 4       90004             62180        34.8        31302          30878
# ..        ...               ...         ...          ...            ...
# 314     93552             38158        28.4        18711          19447
# 315     93553              2138        43.3         1121           1017
# 316     93560             18910        32.4         9491           9419
# 317     93563               388        44.5          263            125
# 318     93591              7285        30.9         3653           3632
#
#      Total Households  Average Household Size
# 0                   1                    1.00
# 1               12971                    4.40
# 2               11731                    4.36
# 3               15642                    4.22
# 4               22547                    2.73
# ..                ...                     ...
# 314              9690                    3.93
# 315               816                    2.62
# 316              6469                    2.92
# 317               103                    2.53
# 318              1982                    3.67
#
# [319 rows x 7 columns]

# %% [markdown]
# # 数据填充

# %% [markdown]
# ## 检测缺失值

# %%
df = pd.DataFrame(np.random.rand(9, 5), columns=list('ABCDE'))

# 插入 T 列，并打上时间戳
df.insert(value=pd.Timestamp('2017-10-1'), loc=0, column='Time')

# 将 1, 3, 5 列的 1，3，5 行置为缺失值
df.iloc[[1, 3, 5, 7], [0, 2, 4]] = np.nan

# 将 2, 4, 6 列的 2，4，6 行置为缺失值
df.iloc[[2, 4, 6, 8], [1, 3, 5]] = np.nan
df
# Out:
#         Time         A         B         C         D         E
# 0 2017-10-01  0.621809  0.491162  0.619517  0.450179  0.213620
# 1        NaT  0.627360       NaN  0.299793       NaN  0.584162
# 2 2017-10-01       NaN  0.556981       NaN  0.526374       NaN
# 3        NaT  0.830023       NaN  0.088254       NaN  0.914760
# 4 2017-10-01       NaN  0.408012       NaN  0.486243       NaN
# 5        NaT  0.810544       NaN  0.784837       NaN  0.374484
# 6 2017-10-01       NaN  0.717019       NaN  0.424978       NaN
# 7        NaT  0.692959       NaN  0.020433       NaN  0.947325
# 8 2017-10-01       NaN  0.591955       NaN  0.093686       NaN

# %%
df.isna()
# Out:
#     Time      A      B      C      D      E
# 0  False  False  False  False  False  False
# 1   True  False   True  False   True  False
# 2  False   True  False   True  False   True
# 3   True  False   True  False   True  False
# 4  False   True  False   True  False   True
# 5   True  False   True  False   True  False
# 6  False   True  False   True  False   True
# 7   True  False   True  False   True  False
# 8  False   True  False   True  False   True

# %%
df.fillna(0)
# Out:
#                   Time         A         B         C         D         E
# 0  2017-10-01 00:00:00  0.621809  0.491162  0.619517  0.450179  0.213620
# 1                    0  0.627360  0.000000  0.299793  0.000000  0.584162
# 2  2017-10-01 00:00:00  0.000000  0.556981  0.000000  0.526374  0.000000
# 3                    0  0.830023  0.000000  0.088254  0.000000  0.914760
# 4  2017-10-01 00:00:00  0.000000  0.408012  0.000000  0.486243  0.000000
# 5                    0  0.810544  0.000000  0.784837  0.000000  0.374484
# 6  2017-10-01 00:00:00  0.000000  0.717019  0.000000  0.424978  0.000000
# 7                    0  0.692959  0.000000  0.020433  0.000000  0.947325
# 8  2017-10-01 00:00:00  0.000000  0.591955  0.000000  0.093686  0.000000

# %%
# 使用缺失值前面的值进行填充
df.fillna(method='pad')
# Out:
#         Time         A         B         C         D         E
# 0 2017-10-01  0.621809  0.491162  0.619517  0.450179  0.213620
# 1 2017-10-01  0.627360  0.491162  0.299793  0.450179  0.584162
# 2 2017-10-01  0.627360  0.556981  0.299793  0.526374  0.584162
# 3 2017-10-01  0.830023  0.556981  0.088254  0.526374  0.914760
# 4 2017-10-01  0.830023  0.408012  0.088254  0.486243  0.914760
# 5 2017-10-01  0.810544  0.408012  0.784837  0.486243  0.374484
# 6 2017-10-01  0.810544  0.717019  0.784837  0.424978  0.374484
# 7 2017-10-01  0.692959  0.717019  0.020433  0.424978  0.947325
# 8 2017-10-01  0.692959  0.591955  0.020433  0.093686  0.947325

# %%
# 后面的值
df.fillna(method='bfill')
# Out:
#         Time         A         B         C         D         E
# 0 2017-10-01  0.621809  0.491162  0.619517  0.450179  0.213620
# 1 2017-10-01  0.627360  0.556981  0.299793  0.526374  0.584162
# 2 2017-10-01  0.830023  0.556981  0.088254  0.526374  0.914760
# 3 2017-10-01  0.830023  0.408012  0.088254  0.486243  0.914760
# 4 2017-10-01  0.810544  0.408012  0.784837  0.486243  0.374484
# 5 2017-10-01  0.810544  0.717019  0.784837  0.424978  0.374484
# 6 2017-10-01  0.692959  0.717019  0.020433  0.424978  0.947325
# 7 2017-10-01  0.692959  0.591955  0.020433  0.093686  0.947325
# 8 2017-10-01       NaN  0.591955       NaN  0.093686       NaN

# %%
df.iloc[[3, 5], [1, 3, 5]] = np.nan

# %%
df.fillna(method='pad')
# Out:
#         Time         A         B         C         D         E
# 0 2017-10-01  0.621809  0.491162  0.619517  0.450179  0.213620
# 1 2017-10-01  0.627360  0.491162  0.299793  0.450179  0.584162
# 2 2017-10-01  0.627360  0.556981  0.299793  0.526374  0.584162
# 3 2017-10-01  0.627360  0.556981  0.299793  0.526374  0.584162
# 4 2017-10-01  0.627360  0.408012  0.299793  0.486243  0.584162
# 5 2017-10-01  0.627360  0.408012  0.299793  0.486243  0.584162
# 6 2017-10-01  0.627360  0.717019  0.299793  0.424978  0.584162
# 7 2017-10-01  0.692959  0.717019  0.020433  0.424978  0.947325
# 8 2017-10-01  0.692959  0.591955  0.020433  0.093686  0.947325

# %%
# 最多填充一项
df.fillna(method='pad', limit=1)
# Out:
#         Time         A         B         C         D         E
# 0 2017-10-01  0.621809  0.491162  0.619517  0.450179  0.213620
# 1 2017-10-01  0.627360  0.491162  0.299793  0.450179  0.584162
# 2 2017-10-01  0.627360  0.556981  0.299793  0.526374  0.584162
# 3 2017-10-01       NaN  0.556981       NaN  0.526374       NaN
# 4 2017-10-01       NaN  0.408012       NaN  0.486243       NaN
# 5 2017-10-01       NaN  0.408012       NaN  0.486243       NaN
# 6 2017-10-01       NaN  0.717019       NaN  0.424978       NaN
# 7 2017-10-01  0.692959  0.717019  0.020433  0.424978  0.947325
# 8 2017-10-01  0.692959  0.591955  0.020433  0.093686  0.947325

# %%
df.fillna(df.mean()['C':'E'])
# Out:
#         Time         A         B         C         D         E
# 0 2017-10-01  0.621809  0.491162  0.619517  0.450179  0.213620
# 1        NaT  0.627360       NaN  0.299793  0.396292  0.584162
# 2 2017-10-01       NaN  0.556981  0.313248  0.526374  0.581702
# 3        NaT       NaN       NaN  0.313248  0.396292  0.581702
# 4 2017-10-01       NaN  0.408012  0.313248  0.486243  0.581702
# 5        NaT       NaN       NaN  0.313248  0.396292  0.581702
# 6 2017-10-01       NaN  0.717019  0.313248  0.424978  0.581702
# 7        NaT  0.692959       NaN  0.020433  0.396292  0.947325
# 8 2017-10-01       NaN  0.591955  0.313248  0.093686  0.581702

# %% [markdown]
# ## 插值填充

# %%
# 生成一个 DataFrame
df = pd.DataFrame({'A': [1.1, 2.2, np.nan, 4.5, 5.7, 6.9],
                   'B': [.21, np.nan, np.nan, 3.1, 11.7, 13.2]})
df
# Out:
#      A      B
# 0  1.1   0.21
# 1  2.2    NaN
# 2  NaN    NaN
# 3  4.5   3.10
# 4  5.7  11.70
# 5  6.9  13.20

# %% [markdown]
# 对于 interpolate() 支持的插值算法，也就是 method=。下面给出几条选择的建议：
#
# - 如果你的数据增长速率越来越快，可以选择 method='quadratic'二次插值。
# - 如果数据集呈现出累计分布的样子，推荐选择 method='pchip'。
# - 如果需要填补缺省值，以平滑绘图为目标，推荐选择 method='akima'。
#
# 当然，最后提到的 method='akima'，需要你的环境中安装了 Scipy 库。除此之外，method='barycentric' 和 method='pchip' 同样也需要 Scipy 才能使用。

# %%
df_interpolate = df.interpolate()
df_interpolate
# Out:
#       A          B
# 0  1.10   0.210000
# 1  2.20   1.173333
# 2  3.35   2.136667
# 3  4.50   3.100000
# 4  5.70  11.700000
# 5  6.90  13.200000

# %% [markdown]
# # 数据可视化

# %%
df_interpolate.plot()

# %%
df_interpolate.plot(kind='bar')
